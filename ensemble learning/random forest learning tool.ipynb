# %%
import random
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification

# %%
X,y = make_classification(n_features=5, n_redundant=0, n_informative=5,n_clusters_per_class=1)

# %%
df = pd.DataFrame(X,columns=['col1','col2','col3','col4','col5'])
df['target'] = y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0 -0.763860 -1.412792  1.026419 -2.063661  0.922637       1
# 1  0.321229 -1.861611 -0.669411 -4.620306  1.456745       1
# 2  0.800370  1.156179  1.165594 -2.206933 -1.851769       0
# 3  0.832152  2.523221  0.482685 -1.664492 -1.658135       0
# 4  3.296308  0.243403 -0.250845 -1.132577  0.194817       0

# %%
# function for row sampling

def sample_rows(df,percent):
  return df.sample(int(percent*df.shape[0]),replace=True)

# %%
# function for feature sampling
def sample_features(df,percent):
  cols = random.sample(df.columns.tolist()[:-1],int(percent*(df.shape[1]-1)))
  new_df = df[cols]
  new_df['target'] = df['target']
  return new_df

# %%
# function for combined sampling

def combined_sampling(df,row_percent,col_percent):
  new_df = sample_rows(df,row_percent)
  return sample_features(new_df,col_percent)

# %%
df1 = combined_sampling(df,0.5,0.5)
# Out:
# C:\Users\Deepti Devaiah\AppData\Local\Temp\ipykernel_11012\1939090737.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']

# %%
df2 = combined_sampling(df,0.5,0.5)
# Out:
# C:\Users\Deepti Devaiah\AppData\Local\Temp\ipykernel_11012\1939090737.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']

# %%
df3 = combined_sampling(df,0.5,0.5)
# Out:
# C:\Users\Deepti Devaiah\AppData\Local\Temp\ipykernel_11012\1939090737.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']

# %%
print(df1.columns)
print(df2.columns)
print(df3.columns)
# Out:
# Index(['col5', 'col3', 'target'], dtype='object')
# Index(['col5', 'col4', 'target'], dtype='object')
# Index(['col4', 'col2', 'target'], dtype='object')

# %%
df3
# Out:
#         col4      col2  target
# 83 -2.054742  3.397443       0
# 91  0.416427  0.236277       0
# 73  2.050854  0.323236       1
# 57 -1.882310 -0.020766       0
# 66 -0.330096  2.918297       0
# 66 -0.330096  2.918297       0
# 41 -0.543395 -0.196633       0
# 63  0.759076 -0.540163       0
# 26 -0.092738  0.837506       0
# 56 -0.107994  0.346267       0
# 44 -2.038001 -2.573213       1
# 94  0.446422  0.067706       1
# 1  -4.620306 -1.861611       1
# 54 -0.830878 -0.546241       0
# 45 -0.953061 -0.230320       1
# 79 -0.844811 -0.472574       1
# 87 -1.780135 -0.621752       0
# 81  1.488414 -0.498633       1
# 49  0.339460 -0.771179       1
# 46  0.115764 -0.922336       0
# 60 -1.279765  0.091733       0
# 30 -1.903229 -1.530820       1
# 28 -1.488829  1.007890       0
# 95 -1.762291 -1.942504       1
# 36 -1.872011  1.144480       1
# 92  0.305405  0.515022       1
# 59 -1.584351 -1.077605       0
# 97 -2.548978 -0.996212       1
# 4  -1.132577  0.243403       0
# 56 -0.107994  0.346267       0
# 41 -0.543395 -0.196633       0
# 80  1.410139 -0.735610       0
# 41 -0.543395 -0.196633       0
# 9   1.111672 -2.106144       1
# 64 -0.774579 -0.234257       1
# 0  -2.063661 -1.412792       1
# 27 -1.486482  3.597332       0
# 34 -0.112129 -0.875905       0
# 13 -0.269431 -2.563262       1
# 75 -0.008012 -0.086087       0
# 88 -1.540351  1.541525       0
# 13 -0.269431 -2.563262       1
# 76 -0.928438 -0.671367       1
# 50 -1.137354  2.073811       0
# 33  1.325789 -1.448674       1
# 26 -0.092738  0.837506       0
# 52 -0.064432  2.085738       0
# 23 -0.351747  1.246944       0
# 72 -2.812557 -1.345801       1
# 69 -0.997342 -0.826412       1

# %%
from sklearn.tree import DecisionTreeClassifier
clf1 = DecisionTreeClassifier()
clf2 = DecisionTreeClassifier()
clf3 = DecisionTreeClassifier()

# %%
clf1.fit(df1.iloc[:,0:2],df1.iloc[:,-1])
clf2.fit(df2.iloc[:,0:2],df2.iloc[:,-1])
clf3.fit(df3.iloc[:,0:2],df3.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(clf1)
# Out:
# [Text(0.5555555555555556, 0.9, 'x[0] <= 0.376\ngini = 0.497\nsamples = 50\nvalue = [23, 27]'),
#  Text(0.3333333333333333, 0.7, 'x[1] <= 0.762\ngini = 0.153\nsamples = 24\nvalue = [22, 2]'),
#  Text(0.4444444444444444, 0.8, 'True  '),
#  Text(0.2222222222222222, 0.5, 'x[1] <= 0.252\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.1111111111111111, 0.3, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3333333333333333, 0.3, 'x[0] <= -1.104\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2222222222222222, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4444444444444444, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.4444444444444444, 0.5, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.7777777777777778, 0.7, 'x[1] <= 2.319\ngini = 0.074\nsamples = 26\nvalue = [1, 25]'),
#  Text(0.6666666666666667, 0.8, '  False'),
#  Text(0.6666666666666666, 0.5, 'gini = 0.0\nsamples = 25\nvalue = [0, 25]'),
#  Text(0.8888888888888888, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]')]

# %%
plot_tree(clf2)
# Out:
# [Text(0.6071428571428571, 0.9285714285714286, 'x[0] <= 0.305\ngini = 0.461\nsamples = 50\nvalue = [18, 32]'),
#  Text(0.42857142857142855, 0.7857142857142857, 'x[1] <= -0.003\ngini = 0.375\nsamples = 20\nvalue = [15, 5]'),
#  Text(0.5178571428571428, 0.8571428571428572, 'True  '),
#  Text(0.2857142857142857, 0.6428571428571429, 'x[1] <= -0.476\ngini = 0.231\nsamples = 15\nvalue = [13, 2]'),
#  Text(0.21428571428571427, 0.5, 'x[1] <= -0.514\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.14285714285714285, 0.35714285714285715, 'x[1] <= -1.067\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.07142857142857142, 0.21428571428571427, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.21428571428571427, 0.21428571428571427, 'x[0] <= -0.605\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.14285714285714285, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2857142857142857, 0.07142857142857142, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.2857142857142857, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.35714285714285715, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.5714285714285714, 0.6428571428571429, 'x[0] <= -0.062\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.5, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6428571428571429, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7857142857142857, 0.7857142857142857, 'x[1] <= 0.354\ngini = 0.18\nsamples = 30\nvalue = [3, 27]'),
#  Text(0.6964285714285714, 0.8571428571428572, '  False'),
#  Text(0.7142857142857143, 0.6428571428571429, 'gini = 0.0\nsamples = 25\nvalue = [0, 25]'),
#  Text(0.8571428571428571, 0.6428571428571429, 'x[1] <= 1.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.7857142857142857, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9285714285714286, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]')]

# %%
plot_tree(clf3)
# Out:
# [Text(0.5, 0.9375, 'x[1] <= -1.212\ngini = 0.493\nsamples = 50\nvalue = [28.0, 22.0]'),
#  Text(0.4375, 0.8125, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.46875, 0.875, 'True  '),
#  Text(0.5625, 0.8125, 'x[1] <= -0.213\ngini = 0.42\nsamples = 40\nvalue = [28, 12]'),
#  Text(0.53125, 0.875, '  False'),
#  Text(0.375, 0.6875, 'x[1] <= -0.519\ngini = 0.498\nsamples = 15\nvalue = [7, 8]'),
#  Text(0.3125, 0.5625, 'x[1] <= -0.647\ngini = 0.463\nsamples = 11\nvalue = [7, 4]'),
#  Text(0.25, 0.4375, 'x[0] <= -0.52\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.125, 0.3125, 'x[1] <= -1.037\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.0625, 0.1875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1875, 0.1875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.375, 0.3125, 'x[0] <= 0.228\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.3125, 0.1875, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.4375, 0.1875, 'x[1] <= -0.753\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.375, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.375, 0.4375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4375, 0.5625, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.75, 0.6875, 'x[0] <= 0.149\ngini = 0.269\nsamples = 25\nvalue = [21, 4]'),
#  Text(0.625, 0.5625, 'x[0] <= -1.706\ngini = 0.091\nsamples = 21\nvalue = [20, 1]'),
#  Text(0.5625, 0.4375, 'x[0] <= -1.877\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.5, 0.3125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.625, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6875, 0.4375, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.875, 0.5625, 'x[0] <= 0.431\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.8125, 0.4375, 'x[1] <= 0.376\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.75, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.875, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9375, 0.4375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]')]
